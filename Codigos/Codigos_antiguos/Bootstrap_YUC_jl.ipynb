# %%
# Prueba
using CSV
using DataFrames

# %%
prueba=CSV.read("/Users/damian/Documents/Tesis maestria/Bootstraps/Bases/Casilla_por_casilla_gubernatura_280627_YUC.csv", DataFrame)
# Out:
# 2979×35 DataFrame
#   Row │ ID ESTADO  NOMBRE ESTADO  CABECERA DISTRITAL LOCAL  ID MUNICIPIO  DIST ⋯
#       │ Int64      String15       String15                  Int64         Int6 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │        31  YUCATÁN        UMAN                                 1       ⋯
#     2 │        31  YUCATÁN        UMAN                                 1
#     3 │        31  YUCATÁN        UMAN                                 1
#     4 │        31  YUCATÁN        UMAN                                 1
#     5 │        31  YUCATÁN        UMAN                                 1       ⋯
#     6 │        31  YUCATÁN        UMAN                                 1
#     7 │        31  YUCATÁN        UMAN                                 1
#     8 │        31  YUCATÁN        UMAN                                 1
#   ⋮   │     ⋮            ⋮                   ⋮                   ⋮           ⋮ ⋱
# ...

# %%
prueba[:,:"ESTATUS ACTA"]=="PENDIENTE DE CAPTURA"
# Out:
# false
