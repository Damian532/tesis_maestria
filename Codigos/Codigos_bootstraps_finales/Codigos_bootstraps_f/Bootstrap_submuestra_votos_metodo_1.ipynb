# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import math
import random
import seaborn as sns
import matplotlib.pyplot as plt
# Sirve para medir la velocidad de una función
import time
import datetime
# %load_ext line_profiler
import sys
sys.path.insert(1, '/Users/damian/Documents/Tesis maestria/Bootstraps_codigos_bases/Codigos/Funciones_utiles_f')
import funciones_aux_bootstrap_f_r as fab

# %% [markdown]
# # Bootstrap por Submuestra de Votos - Método 1
#
# **Nota**: Este notebook es parte del **Paso 2** del flujo de ejecución del proyecto.
#
# **Requisitos previos**:
# - Haber ejecutado: `Codigos/Codigo_creacion_base_analisis/Creacion_base_analsis.ipynb`
# - Archivo de entrada: `Bases/Base elecciones analsis/base_elecciones_yuc_analsis.csv`
#
# **Salida**:
# - Resultados guardados en: `Bases finales rep/Bootstrap votos/Metodo 1/`
#
# Para más información sobre el flujo completo, consultar el `README.md` del repositorio.

# %% [markdown]
# Este método de bootstrap (bayesiano) por votos consiste en lo siguiente
#
# 1. Se muestrea $n$ casillas.
# 2. De las $n$ casillas se muestrean $k$ votos.
# 3. Con estos $k$ votos se calculan los pesos Dirichlet para cada población (en total son 1000).
# 4. Se completan $1000$ poblaciones.
# 5. Con las poblaciones se obtienen la estimación puntual.
#
# Se repite este proceso para $l$ bootstraps (normalmente son 1000) y con estos bootstraps se obtienen todas las métricas (errores, tamaño de los intervalos, coberturas, etc).

# %%
# Importamos los datos para el análisis
df_act_yuc_i=pd.read_csv(r"/Users/damian/Documents/Tesis maestria/Bootstraps_codigos_bases/Bases/Base elecciones analsis/base_elecciones_yuc_analsis.csv", index_col=0)
df_act_yuc_i
# Out:
#       ID ESTADO NOMBRE ESTADO  DISTRITO  SECCION  CASILLA  ID CASILLA  \
# 0            31       YUCATÁN        12        1  '0001B1           1
# 1            31       YUCATÁN        12        1  '0001C1           2
# 2            31       YUCATÁN        12        1  '0001C2           3
# 3            31       YUCATÁN        12        2  '0002B1           4
# 4            31       YUCATÁN        12        4  '0004B1           6
# ...         ...           ...       ...      ...      ...         ...
# 2836         31       YUCATÁN         3     1195  '1195V1        2967
# 2837         31       YUCATÁN         5     1197  '1197V1        2969
# 2838         31       YUCATÁN         8     1199  '1199V1        2971
# 2839         31       YUCATÁN         9     1200  '1200V1        2972
# 2840         31       YUCATÁN        18     1207  '1207V1        2979
#
#      ESTATUS ACTA    PAN    PRI  PRD  ...  CANDIDATOS NO REGISTRADOS  \
# 0       COMPUTADA  171.0  107.0  3.0  ...                        0.0
# 1       COMPUTADA  177.0  104.0  0.0  ...                        0.0
# 2       COMPUTADA  176.0  100.0  1.0  ...                        0.0
# 3       COMPUTADA   46.0   33.0  2.0  ...                        0.0
# 4       COMPUTADA  110.0   96.0  7.0  ...                        0.0
# ...           ...    ...    ...  ...  ...                        ...
# 2836    COMPUTADA    2.0    0.0  0.0  ...                        0.0
# 2837    COMPUTADA    2.0    1.0  0.0  ...                        0.0
# 2838    COMPUTADA    2.0    0.0  0.0  ...                        0.0
# 2839    COMPUTADA    0.0    0.0  0.0  ...                        0.0
# 2840    COMPUTADA    1.0    0.0  0.0  ...                        0.0
#
#       VOTOS NULOS  LISTA NOMINAL  TOTAL  PARTICIPACIÓN  JOAQUIN_DIAZ_MENA  \
# 0            12.0          596.0  532.0       0.892617              209.0
# 1            11.0          596.0  547.0       0.917785              208.0
# 2            13.0          595.0  542.0       0.910924              228.0
# 3             3.0          174.0  162.0       0.931034               71.0
# 4            14.0          550.0  513.0       0.932727              275.0
# ...           ...            ...    ...            ...                ...
# 2836          0.0            0.0    2.0       0.000000                0.0
# 2837          0.0            0.0    5.0       0.000000                2.0
# 2838          0.0            0.0    3.0       0.000000                1.0
# 2839          0.0            0.0    1.0       0.000000                1.0
# 2840          0.0            0.0    1.0       0.000000                0.0
#
#       RENAN_BARRERA_CONCHA  VIDA_ARAVARI_GOMEZ_HERRERA  \
# 0                    290.0                        18.0
# 1                    299.0                        29.0
# 2                    289.0                        11.0
# 3                     79.0                         7.0
# 4                    207.0                        10.0
# ...                    ...                         ...
# 2836                   2.0                         0.0
# 2837                   3.0                         0.0
# 2838                   2.0                         0.0
# 2839                   0.0                         0.0
# 2840                   1.0                         0.0
#
#       YAMIL_JASMIN_LOPEZ_MANRIQUE  VOTOS_NULOS_CAND_NO_REGIS
# 0                             3.0                       12.0
# 1                             0.0                       11.0
# 2                             1.0                       13.0
# 3                             2.0                        3.0
# 4                             7.0                       14.0
# ...                           ...                        ...
# 2836                          0.0                        0.0
# 2837                          0.0                        0.0
# 2838                          0.0                        0.0
# 2839                          0.0                        0.0
# 2840                          0.0                        0.0
#
# [2841 rows x 33 columns]

# %%
# Datos reales de la proporción
prop_reales=df_act_yuc_i[["JOAQUIN_DIAZ_MENA","RENAN_BARRERA_CONCHA","VIDA_ARAVARI_GOMEZ_HERRERA","YAMIL_JASMIN_LOPEZ_MANRIQUE","VOTOS_NULOS_CAND_NO_REGIS"]].sum()/df_act_yuc_i[["JOAQUIN_DIAZ_MENA","RENAN_BARRERA_CONCHA","VIDA_ARAVARI_GOMEZ_HERRERA","YAMIL_JASMIN_LOPEZ_MANRIQUE","VOTOS_NULOS_CAND_NO_REGIS"]].sum().sum()
prop_reales
# Out:
# JOAQUIN_DIAZ_MENA              0.515125
# RENAN_BARRERA_CONCHA           0.421366
# VIDA_ARAVARI_GOMEZ_HERRERA     0.036792
# YAMIL_JASMIN_LOPEZ_MANRIQUE    0.005249
# VOTOS_NULOS_CAND_NO_REGIS      0.021467
# dtype: float64

# %% [markdown]
# ## Sin estratificar

# %%
def bootstrap_votos_simple(df, num_boot: int=1000, n_sample=None, n_vot_sub=2000, semilla=1):

    est_punt_list=[]

    inter_list=[]

    # Número total de votos
    n_votos=int(df[["JOAQUIN_DIAZ_MENA","RENAN_BARRERA_CONCHA","VIDA_ARAVARI_GOMEZ_HERRERA","YAMIL_JASMIN_LOPEZ_MANRIQUE","VOTOS_NULOS_CAND_NO_REGIS"]].sum().sum())


    for i in range(num_boot):

        # Semilla para que el código sea reproducible
        rng = np.random.default_rng((i+1)+(num_boot*semilla))

        df_stra_sam = df.sample(n=n_sample, random_state= rng)

        df_stra_sam=np.array(df_stra_sam[["JOAQUIN_DIAZ_MENA","RENAN_BARRERA_CONCHA","VIDA_ARAVARI_GOMEZ_HERRERA","YAMIL_JASMIN_LOPEZ_MANRIQUE","VOTOS_NULOS_CAND_NO_REGIS"]])

        # Votos por candidato en la muestra
        #n_votos_cand=df_stra_sam.sum(0).astype(int)

        # Semilla para que el código sea reproducible
        rng = np.random.default_rng((i+1)+(num_boot*(semilla+1)))

        # Submuestra de votos (en este caso son 2000)
        # Corrección del código inicial lo correcto es utilizar la distribución hipergeométrica multivariada.
        # Puesto que, se esta haciendo muestreo sin reemplazo y si utilizas la multinomial es muestreo con reemplazo.
        # La diferencia es mínima pero la hipergeométrica multivariada es la correcta.
        votos_subm=rng.multivariate_hypergeometric(colors=df_stra_sam.sum(0).astype(int), nsample=n_vot_sub)

        # Semilla para que el código sea reproducible
        rng = np.random.default_rng((i+1)+(num_boot*(semilla+2)))

        # Los pesos de la distribución Dirichlet
        pesos_bootstrap=rng.dirichlet(votos_subm, 1000)

        # Semilla para que el código sea reproducible
        rng = np.random.default_rng((i+1)+(num_boot*(semilla+3)))

        # Simulamos las 1000 poblaciones de votos
        votos_sim=rng.multinomial(n=n_votos,  pvals=pesos_bootstrap)

        # Obtenemos las proporciones de los votos
        array_res=(votos_sim)/n_votos

        # Los valores de los intervalos de probabilidad lower y upper
        inter_prob=np.concatenate((np.apply_along_axis(fab.inter_prob_l, axis=0, arr=array_res),np.apply_along_axis(fab.inter_prob_u, axis=0, arr=array_res)))
        
        # Estimaciones puntuales
        est_puntual=array_res.mean(0)

        # Guardamos las estimaciones puntuales
        est_punt_list.append(est_puntual)

        # Guardamos los intervalos
        inter_list.append(inter_prob)
        #print(i)
        
    print(df_stra_sam.shape[0])
    
    # Todas las estimaciones puntuales
    array_est_punt=np.array(est_punt_list)

    array_inter_prob=np.array(inter_list)

    return array_inter_prob,array_est_punt

# %%
# Para medir cuanto tiempo se tarda en correr
# Boostrap por votos
inter_prob_v, est_punt_v=bootstrap_votos_simple(df_act_yuc_i, num_boot=1000, n_sample=350, n_vot_sub=15000, semilla=5)
# Out:
# 350

# %%
# Para medir cuanto tiempo se tarda en correr en promedio
# %timeit bootstrap_votos_simple(df_act_yuc_i, num_boot=1000, n_sample=250, n_vot_sub=5000)
# Out:
# 250
# 250
# 250
# 250
# 250
# 250
# 250
# 250
# 1.24 s ± 135 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Guardamos las bases
df_metr_boot_v, df_error_max_v, df_can_cob_v = fab.metricas_bootstrap(prop_reales, inter_prob_v, est_punt_v, porcenta_tama=20000)

# %%
df_can_cob_v
# Out:
#                      Candidato  Numero_total_cob  Cobertura  Porcenta_tama
# 0            JOAQUIN_DIAZ_MENA               679      0.679          20000
# 1         RENAN_BARRERA_CONCHA               676      0.676          20000
# 2   VIDA_ARAVARI_GOMEZ_HERRERA               810      0.810          20000
# 3    VOTOS_NULOS_CAND_NO_REGIS               902      0.902          20000
# 4  YAMIL_JASMIN_LOPEZ_MANRIQUE               833      0.833          20000

# %%
df_metr_boot_v.groupby(["Candidato"]).agg({'Longitud_intervalo':['median','mean']})
# Out:
#                             Longitud_intervalo
#                                         median      mean
# Candidato
# JOAQUIN_DIAZ_MENA                     0.016031  0.016035
# RENAN_BARRERA_CONCHA                  0.015820  0.015834
# VIDA_ARAVARI_GOMEZ_HERRERA            0.006027  0.006030
# VOTOS_NULOS_CAND_NO_REGIS             0.004639  0.004640
# YAMIL_JASMIN_LOPEZ_MANRIQUE           0.002297  0.002303

# %%
df_error_max_v.describe(percentiles=[0.025,0.975])
# Out:
#        Num_bootstrap    Error_max  Porcenta_tama
# count    1000.000000  1000.000000         1000.0
# mean      500.500000     0.023007        20000.0
# std       288.819436     0.013948            0.0
# min         1.000000     0.001148        20000.0
# 2.5%       25.975000     0.004865        20000.0
# 50%       500.500000     0.020348        20000.0
# 97.5%     975.025000     0.058966        20000.0
# max      1000.000000     0.099548        20000.0

# %%
# Base para poder hacer las gráficas de mínima cobertura e intervalos más largos
df_metr_boot_c_v=df_metr_boot_v.drop(columns="Cobertura").merge(df_can_cob_v[["Candidato","Cobertura"]], on=["Candidato"], how='left')
df_metr_boot_c_v
# Out:
#       Num_bootstrap  cuantil_025  cuantil_975  Longitud_intervalo  \
# 0                 1     0.497658     0.588763            0.091105
# 1                 2     0.485114     0.569721            0.084607
# 2                 3     0.503929     0.586214            0.082285
# 3                 4     0.459804     0.548642            0.088838
# 4                 5     0.468864     0.555498            0.086634
# ...             ...          ...          ...                 ...
# 4995            996     0.009498     0.033051            0.023553
# 4996            997     0.009061     0.034651            0.025590
# 4997            998     0.012607     0.037701            0.025094
# 4998            999     0.016871     0.046415            0.029544
# 4999           1000     0.018933     0.049326            0.030394
#
#       Estamacion_puntual  Porcentaje_real                  Candidato  \
# 0               0.546197         0.515125          JOAQUIN_DIAZ_MENA
# 1               0.527967         0.515125          JOAQUIN_DIAZ_MENA
# 2               0.545419         0.515125          JOAQUIN_DIAZ_MENA
# 3               0.502344         0.515125          JOAQUIN_DIAZ_MENA
# 4               0.511559         0.515125          JOAQUIN_DIAZ_MENA
# ...                  ...              ...                        ...
# 4995            0.019788         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4996            0.020148         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4997            0.023844         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4998            0.030024         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4999            0.032280         0.021467  VOTOS_NULOS_CAND_NO_REGIS
#
#          Error  Porcenta_tama  Cobertura
# 0     0.031071          20000      0.933
# 1     0.012841          20000      0.933
# 2     0.030294          20000      0.933
# 3     0.012781          20000      0.933
# 4     0.003566          20000      0.933
# ...        ...            ...        ...
# 4995  0.001679          20000      0.925
# 4996  0.001319          20000      0.925
# 4997  0.002377          20000      0.925
# 4998  0.008557          20000      0.925
# 4999  0.010813          20000      0.925
#
# [5000 rows x 10 columns]

# %%
# Candidato con intervalo más largo
df_inter_lar_v=df_metr_boot_v.groupby(["Candidato"]).agg({'Longitud_intervalo':'mean'}).reset_index()
df_inter_lar_v["Porcenta_tama"]=250
candidato_mas_largo_v=df_inter_lar_v[df_inter_lar_v["Longitud_intervalo"]==df_inter_lar_v["Longitud_intervalo"].max()]["Candidato"].values[0]
df_metr_boot_c_v[df_metr_boot_c_v["Candidato"]==candidato_mas_largo_v]["Longitud_intervalo"].describe()
# Out:
# count    1000.000000
# mean        0.086956
# std         0.002498
# min         0.078975
# 25%         0.085254
# 50%         0.086927
# 75%         0.088623
# max         0.094038
# Name: Longitud_intervalo, dtype: float64

# %%
# Candidato con intervalo más largo
df_inter_lar_v=df_metr_boot_v.groupby(["Candidato"]).agg({'Longitud_intervalo':'mean'}).reset_index()
df_inter_lar_v["Porcenta_tama"]=250
candidato_mas_largo_v=df_inter_lar_v[df_inter_lar_v["Longitud_intervalo"]==df_inter_lar_v["Longitud_intervalo"].max()]["Candidato"].values[0]

# %%
# Candidato con menor cobertura
candidato_cober_men_v=df_can_cob_v[df_can_cob_v["Cobertura"]==df_can_cob_v["Cobertura"].min()]["Candidato"].values[0]

# %%
df_error_max_v.describe(percentiles=[0.025,0.975])
# Out:
#        Num_bootstrap    Error_max  Porcenta_tama
# count    1000.000000  1000.000000         1000.0
# mean      500.500000     0.013322          250.0
# std       288.819436     0.007878            0.0
# min         1.000000     0.001436          250.0
# 2.5%       25.975000     0.002791          250.0
# 50%       500.500000     0.011537          250.0
# 97.5%     975.025000     0.030890          250.0
# max      1000.000000     0.051513          250.0

# %%
sns.set_theme();
ax = sns.catplot(
    data=df_error_max_v, x="Porcenta_tama", y="Error_max",
    kind="point", height=4, aspect=.7, errorbar='pi'
);
ax.set(xlabel='Porcentaje casillas', ylabel='Error');

# %%
# Base para poder hacer las gráficas de mínima cobertura e intervalos más largos
df_metr_boot_c_v=df_metr_boot_v.drop(columns="Cobertura").merge(df_can_cob_v[["Candidato","Cobertura"]], on=["Candidato"], how='left')
df_metr_boot_c_v
# Out:
#       Num_bootstrap  cuantil_025  cuantil_975  Longitud_intervalo  \
# 0                 1     0.493772     0.537227            0.043455
# 1                 2     0.471874     0.515637            0.043763
# 2                 3     0.490195     0.536270            0.046075
# 3                 4     0.478045     0.520293            0.042248
# 4                 5     0.477104     0.521367            0.044263
# ...             ...          ...          ...                 ...
# 4995            996     0.018280     0.031710            0.013429
# 4996            997     0.015120     0.027430            0.012310
# 4997            998     0.020001     0.034218            0.014216
# 4998            999     0.016995     0.029279            0.012284
# 4999           1000     0.015168     0.027829            0.012662
#
#       Estamacion_puntual  Porcentaje_real                  Candidato  \
# 0               0.516363         0.515125          JOAQUIN_DIAZ_MENA
# 1               0.493922         0.515125          JOAQUIN_DIAZ_MENA
# 2               0.513713         0.515125          JOAQUIN_DIAZ_MENA
# 3               0.499337         0.515125          JOAQUIN_DIAZ_MENA
# 4               0.499749         0.515125          JOAQUIN_DIAZ_MENA
# ...                  ...              ...                        ...
# 4995            0.024469         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4996            0.020969         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4997            0.026938         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4998            0.022991         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4999            0.021072         0.021467  VOTOS_NULOS_CAND_NO_REGIS
#
#          Error  Porcenta_tama  Cobertura
# 0     0.001238            250      0.886
# 1     0.021204            250      0.886
# 2     0.001412            250      0.886
# 3     0.015789            250      0.886
# 4     0.015376            250      0.886
# ...        ...            ...        ...
# 4995  0.003002            250      0.930
# 4996  0.000498            250      0.930
# 4997  0.005471            250      0.930
# 4998  0.001524            250      0.930
# 4999  0.000395            250      0.930
#
# [5000 rows x 10 columns]

# %%
facet_kws={'sharey': False, 'sharex': True}
fig, axx =plt.subplots(2,1)
ax_1=sns.pointplot(
    data=df_metr_boot_c_v[df_metr_boot_c_v["Candidato"]==candidato_mas_largo_v], x="Porcenta_tama", y="Longitud_intervalo", errorbar='pi',ax=axx[0]
);
ax_2=sns.pointplot(
    data=df_metr_boot_c_v[df_metr_boot_c_v["Candidato"]==candidato_mas_largo_v].head(1), x="Porcenta_tama", y="Cobertura", ax=axx[1]
)
ax_1.set(xlabel='Porcentaje casillas', ylabel='Longitud intervalo');
ax_2.set(xlabel='Porcentaje casillas', ylabel='Cobertura');

# %%
facet_kws={'sharey': False, 'sharex': True}
fig, axx =plt.subplots(2,1)
ax_1=sns.pointplot(
    data=df_metr_boot_c_v[df_metr_boot_c_v["Candidato"]==candidato_cober_men_v], x="Porcenta_tama", y="Longitud_intervalo", errorbar='pi', ax=axx[0]
);
ax_2=sns.pointplot(
    data=df_metr_boot_c_v[df_metr_boot_c_v["Candidato"]==candidato_cober_men_v].head(1), x="Porcenta_tama", y="Cobertura", ax=axx[1]
)
ax_1.set(xlabel='Casillas en muestra', ylabel='Longitud intervalo');
ax_2.set(xlabel='Casillas en muestra', ylabel='Cobertura');

# %% [markdown]
# ### Bootstraps con distintas muestras de casillas y submuestras de votos

# %%
# Probamos distintos valores de tamaño de la muestra de las casillas y la submuestra de votos
muestra_casillas = [100, 150, 200, 250, 300, 350, 400]
#submuestra_votos = [500, 1000, 1500, 2000, 3000, 4000]
submuestra_votos = [500, 1000, 2000, 5000, 10000, 20000]

# Dataframe donde se guardará todo
df_boostraps_votos_se=pd.DataFrame()

# Contador para el for
k=0

for mc in muestra_casillas:
    for smv in submuestra_votos:
        # Boostrap por votos (sin estratificar)
        inter_prob_v, est_punt_v=bootstrap_votos_simple(df_act_yuc_i, num_boot=1000, n_sample=mc, n_vot_sub=smv, semilla=k+1)
        # Calculamos las métricas
        df_metr_boot_v, df_error_max_v, df_can_cob_v = fab.metricas_bootstrap(prop_reales, inter_prob_v, est_punt_v, porcenta_tama=mc)

        # Los valores de las muestra y submuestras
        df_boostraps_votos_se.loc[k,["Tamaño_muestra_casillas","Tamaño_submuestra_votos"]]=[mc,smv]

        # Las métricas para el error máximo
        df_boostraps_votos_se.loc[k,["Error_maximo_q_025","Error_maximo_mediana","Error_maximo_q_975"]]=df_error_max_v["Error_max"].quantile([0.025,0.5,0.975]).to_list()

        # Calculamos el candidato que tenga intervalos más largos (en promedio)
        candidato_int_m_l=df_metr_boot_v.groupby(["Candidato"]).agg({'Longitud_intervalo':'mean'}).reset_index()["Candidato"].values[0]
        # Candidato con el intervalos más grandes
        df_boostraps_votos_se.loc[k, "Intervalo_M_grande_candidato_nom"]=candidato_int_m_l
        # Cobertura del candidato con el intervalos más grandes
        df_boostraps_votos_se.loc[k, ["Intervalo_M_grande_candidato_cob"]]=df_can_cob_v[df_can_cob_v["Candidato"]==candidato_int_m_l]["Cobertura"].values[0]
        # Las métricas del candidato con los intervalos más grandes
        df_boostraps_votos_se.loc[k,["Intervalo_M_grande_inter_q_025","Intervalo_M_grande_inter_mediana","Intervalo_M_grande_inter_q_975"]]=df_metr_boot_v[df_metr_boot_v["Candidato"]==candidato_int_m_l]["Longitud_intervalo"].quantile([0.025,0.5,0.975]).to_list()

        # Calculamos el candidato con la menor cobertura
        # Candidato con menor cobertura
        candidato_cober_men_v=df_can_cob_v[df_can_cob_v["Cobertura"]==df_can_cob_v["Cobertura"].min()]["Candidato"].values[0]

        # Candidato con el intervalos más grandes
        df_boostraps_votos_se.loc[k, "Cobertura_m_candidato_nom"]=candidato_cober_men_v
        # Cobertura del candidato con menor cobertura
        df_boostraps_votos_se.loc[k, ["Cobertura_m_candidato"]]=df_can_cob_v[df_can_cob_v["Candidato"]==candidato_cober_men_v]["Cobertura"].values[0]
        # Las métricas del candidato con la menor cobertura
        df_boostraps_votos_se.loc[k,["Cobertura_m_inter_q_025","Cobertura_m_inter_mediana","Cobertura_m_inter_q_975"]]=df_metr_boot_v[df_metr_boot_v["Candidato"]==candidato_cober_men_v]["Longitud_intervalo"].quantile([0.025,0.5,0.975]).to_list()

        
        # Coberturas de los candidatos en el bootstrap 
        df_boostraps_votos_se.loc[k, ["Cob_JOAQUIN_DIAZ_MENA","Cob_RENAN_BARRERA_CONCHA","Cob_VIDA_ARAVARI_GOMEZ_HERRERA","Cob_VOTOS_NULOS_CAND_NO_REGIS","Cob_YAMIL_JASMIN_LOPEZ_MANRIQUE"]]=df_can_cob_v.sort_values(by="Candidato")["Cobertura"].to_list()

        k=k+1
        
        print("Muestra casillas:", mc, "Submuestra votos:", smv)
# Out:
# 100
# Muestra casillas: 100 Submuestra votos: 500
# 100
# Muestra casillas: 100 Submuestra votos: 1000
# 100
# Muestra casillas: 100 Submuestra votos: 2000
# 100
# Muestra casillas: 100 Submuestra votos: 5000
# 100
# Muestra casillas: 100 Submuestra votos: 10000
# 100
# Muestra casillas: 100 Submuestra votos: 20000
# 150
# Muestra casillas: 150 Submuestra votos: 500
# 150
# Muestra casillas: 150 Submuestra votos: 1000
# 150
# Muestra casillas: 150 Submuestra votos: 2000
# 150
# Muestra casillas: 150 Submuestra votos: 5000
# 150
# Muestra casillas: 150 Submuestra votos: 10000
# 150
# Muestra casillas: 150 Submuestra votos: 20000
# 200
# Muestra casillas: 200 Submuestra votos: 500
# 200
# Muestra casillas: 200 Submuestra votos: 1000
# 200
# Muestra casillas: 200 Submuestra votos: 2000
# 200
# Muestra casillas: 200 Submuestra votos: 5000
# 200
# Muestra casillas: 200 Submuestra votos: 10000
# 200
# Muestra casillas: 200 Submuestra votos: 20000
# 250
# Muestra casillas: 250 Submuestra votos: 500
# 250
# Muestra casillas: 250 Submuestra votos: 1000
# 250
# Muestra casillas: 250 Submuestra votos: 2000
# 250
# Muestra casillas: 250 Submuestra votos: 5000
# 250
# Muestra casillas: 250 Submuestra votos: 10000
# 250
# Muestra casillas: 250 Submuestra votos: 20000
# 300
# Muestra casillas: 300 Submuestra votos: 500
# 300
# Muestra casillas: 300 Submuestra votos: 1000
# 300
# Muestra casillas: 300 Submuestra votos: 2000
# 300
# Muestra casillas: 300 Submuestra votos: 5000
# 300
# Muestra casillas: 300 Submuestra votos: 10000
# 300
# Muestra casillas: 300 Submuestra votos: 20000
# 350
# Muestra casillas: 350 Submuestra votos: 500
# 350
# Muestra casillas: 350 Submuestra votos: 1000
# 350
# Muestra casillas: 350 Submuestra votos: 2000
# 350
# Muestra casillas: 350 Submuestra votos: 5000
# 350
# Muestra casillas: 350 Submuestra votos: 10000
# 350
# Muestra casillas: 350 Submuestra votos: 20000
# 400
# Muestra casillas: 400 Submuestra votos: 500
# 400
# Muestra casillas: 400 Submuestra votos: 1000
# 400
# Muestra casillas: 400 Submuestra votos: 2000
# 400
# Muestra casillas: 400 Submuestra votos: 5000
# 400
# Muestra casillas: 400 Submuestra votos: 10000
# 400
# Muestra casillas: 400 Submuestra votos: 20000

# %%
df_boostraps_votos_se
# Out:
#    Tamaño_muestra_casillas Tamaño_submuestra_votos  Error_maximo_q_025  \
# 0                      100                     500            0.005386
# 1                      100                    1000            0.004712
# 2                      100                    2000            0.003235
# 3                      100                    5000            0.002548
# 4                      100                   10000            0.002123
# 5                      100                   20000            0.002143
# 6                      150                     500            0.005229
# 7                      150                    1000            0.003878
# 8                      150                    2000            0.003090
# 9                      150                    5000            0.002310
# 10                     150                   10000            0.002163
# 11                     150                   20000            0.001722
# 12                     200                     500            0.005427
# 13                     200                    1000            0.004218
# 14                     200                    2000            0.002968
# 15                     200                    5000            0.002079
# 16                     200                   10000            0.001894
# 17                     200                   20000            0.001667
# 18                     250                     500            0.005198
# 19                     250                    1000            0.003741
# 20                     250                    2000            0.002955
# 21                     250                    5000            0.002160
# 22                     250                   10000            0.001838
# 23                     250                   20000            0.001690
# 24                     300                     500            0.005421
# 25                     300                    1000            0.003709
# 26                     300                    2000            0.002745
# 27                     300                    5000            0.002081
# 28                     300                   10000            0.001843
# 29                     300                   20000            0.001477
# 30                     350                     500            0.005121
# 31                     350                    1000            0.003704
# 32                     350                    2000            0.003371
# 33                     350                    5000            0.001973
# 34                     350                   10000            0.001490
# 35                     350                   20000            0.001396
# 36                     400                     500            0.005189
# 37                     400                    1000            0.003924
# 38                     400                    2000            0.002879
# 39                     400                    5000            0.002115
# 40                     400                   10000            0.001522
# 41                     400                   20000            0.001264
#
#     Error_maximo_mediana  Error_maximo_q_975 Intervalo_M_grande_candidato_nom  \
# 0               0.021258            0.063249                JOAQUIN_DIAZ_MENA
# 1               0.018606            0.049738                JOAQUIN_DIAZ_MENA
# 2               0.014939            0.042026                JOAQUIN_DIAZ_MENA
# 3               0.012566            0.035163                JOAQUIN_DIAZ_MENA
# 4               0.011357            0.033686                JOAQUIN_DIAZ_MENA
# 5               0.011728            0.030550                JOAQUIN_DIAZ_MENA
# 6               0.021237            0.058694                JOAQUIN_DIAZ_MENA
# 7               0.015362            0.047742                JOAQUIN_DIAZ_MENA
# 8               0.012891            0.037597                JOAQUIN_DIAZ_MENA
# 9               0.010446            0.030551                JOAQUIN_DIAZ_MENA
# 10              0.009534            0.026927                JOAQUIN_DIAZ_MENA
# 11              0.009328            0.028790                JOAQUIN_DIAZ_MENA
# 12              0.021016            0.058286                JOAQUIN_DIAZ_MENA
# 13              0.015739            0.047551                JOAQUIN_DIAZ_MENA
# 14              0.012867            0.035327                JOAQUIN_DIAZ_MENA
# 15              0.009734            0.026938                JOAQUIN_DIAZ_MENA
# 16              0.008778            0.025240                JOAQUIN_DIAZ_MENA
# 17              0.008610            0.023586                JOAQUIN_DIAZ_MENA
# 18              0.021154            0.054339                JOAQUIN_DIAZ_MENA
# 19              0.014315            0.039016                JOAQUIN_DIAZ_MENA
# 20              0.011764            0.033788                JOAQUIN_DIAZ_MENA
# 21              0.009324            0.026497                JOAQUIN_DIAZ_MENA
# 22              0.008003            0.022703                JOAQUIN_DIAZ_MENA
# 23              0.007615            0.021261                JOAQUIN_DIAZ_MENA
# 24              0.019843            0.058558                JOAQUIN_DIAZ_MENA
# 25              0.014923            0.040245                JOAQUIN_DIAZ_MENA
# 26              0.011505            0.030472                JOAQUIN_DIAZ_MENA
# 27              0.008705            0.025544                JOAQUIN_DIAZ_MENA
# 28              0.007849            0.021617                JOAQUIN_DIAZ_MENA
# 29              0.006828            0.019392                JOAQUIN_DIAZ_MENA
# 30              0.019415            0.054605                JOAQUIN_DIAZ_MENA
# 31              0.015402            0.041667                JOAQUIN_DIAZ_MENA
# 32              0.011318            0.032030                JOAQUIN_DIAZ_MENA
# 33              0.008369            0.022889                JOAQUIN_DIAZ_MENA
# 34              0.007279            0.020902                JOAQUIN_DIAZ_MENA
# 35              0.006088            0.019202                JOAQUIN_DIAZ_MENA
# 36              0.020284            0.055790                JOAQUIN_DIAZ_MENA
# 37              0.014235            0.039813                JOAQUIN_DIAZ_MENA
# 38              0.010738            0.028953                JOAQUIN_DIAZ_MENA
# 39              0.008148            0.022014                JOAQUIN_DIAZ_MENA
# 40              0.006725            0.019388                JOAQUIN_DIAZ_MENA
# 41              0.006093            0.017969                JOAQUIN_DIAZ_MENA
#
#     Intervalo_M_grande_candidato_cob  Intervalo_M_grande_inter_q_025  \
# 0                              0.904                        0.082385
# 1                              0.864                        0.058117
# 2                              0.795                        0.041190
# 3                              0.638                        0.025967
# 4                              0.521                        0.018489
# 5                              0.383                        0.013125
# 6                              0.939                        0.082181
# 7                              0.890                        0.058142
# 8                              0.844                        0.040996
# 9                              0.694                        0.026107
# 10                             0.598                        0.018450
# 11                             0.459                        0.013107
# 12                             0.925                        0.082045
# 13                             0.899                        0.058211
# 14                             0.848                        0.040923
# 15                             0.752                        0.026122
# 16                             0.655                        0.018496
# 17                             0.495                        0.013058
# 18                             0.933                        0.082299
# 19                             0.937                        0.058384
# 20                             0.888                        0.041082
# 21                             0.784                        0.026075
# 22                             0.688                        0.018473
# 23                             0.548                        0.013052
# 24                             0.936                        0.081647
# 25                             0.923                        0.058251
# 26                             0.898                        0.041173
# 27                             0.824                        0.025994
# 28                             0.709                        0.018490
# 29                             0.598                        0.013048
# 30                             0.937                        0.081946
# 31                             0.927                        0.058268
# 32                             0.890                        0.041253
# 33                             0.840                        0.025926
# 34                             0.751                        0.018481
# 35                             0.638                        0.013143
# 36                             0.941                        0.081981
# 37                             0.923                        0.057995
# 38                             0.925                        0.041034
# 39                             0.856                        0.026079
# 40                             0.778                        0.018461
# 41                             0.672                        0.013124
#
#     Intervalo_M_grande_inter_mediana  Intervalo_M_grande_inter_q_975  \
# 0                           0.087068                        0.092355
# 1                           0.061699                        0.065619
# 2                           0.043556                        0.046247
# 3                           0.027593                        0.029294
# 4                           0.019575                        0.020771
# 5                           0.013908                        0.014773
# 6                           0.086953                        0.092164
# 7                           0.061502                        0.065376
# 8                           0.043618                        0.046324
# 9                           0.027606                        0.029278
# 10                          0.019597                        0.020812
# 11                          0.013859                        0.014769
# 12                          0.086840                        0.092390
# 13                          0.061472                        0.065373
# 14                          0.043436                        0.046147
# 15                          0.027668                        0.029264
# 16                          0.019609                        0.020694
# 17                          0.013898                        0.014710
# 18                          0.086987                        0.091756
# 19                          0.061516                        0.065085
# 20                          0.043594                        0.046091
# 21                          0.027624                        0.029220
# 22                          0.019542                        0.020686
# 23                          0.013863                        0.014718
# 24                          0.087020                        0.092238
# 25                          0.061677                        0.065508
# 26                          0.043529                        0.046355
# 27                          0.027583                        0.029283
# 28                          0.019569                        0.020699
# 29                          0.013885                        0.014760
# 30                          0.086947                        0.092100
# 31                          0.061553                        0.065228
# 32                          0.043539                        0.046039
# 33                          0.027606                        0.029158
# 34                          0.019526                        0.020751
# 35                          0.013911                        0.014800
# 36                          0.086940                        0.091914
# 37                          0.061519                        0.065037
# 38                          0.043563                        0.046352
# 39                          0.027622                        0.029335
# 40                          0.019523                        0.020807
# 41                          0.013914                        0.014749
#
#       Cobertura_m_candidato_nom  Cobertura_m_candidato  \
# 0             JOAQUIN_DIAZ_MENA                  0.904
# 1          RENAN_BARRERA_CONCHA                  0.854
# 2          RENAN_BARRERA_CONCHA                  0.766
# 3          RENAN_BARRERA_CONCHA                  0.626
# 4          RENAN_BARRERA_CONCHA                  0.505
# 5          RENAN_BARRERA_CONCHA                  0.373
# 6   YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.894
# 7             JOAQUIN_DIAZ_MENA                  0.890
# 8          RENAN_BARRERA_CONCHA                  0.842
# 9          RENAN_BARRERA_CONCHA                  0.689
# 10         RENAN_BARRERA_CONCHA                  0.590
# 11         RENAN_BARRERA_CONCHA                  0.447
# 12  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.888
# 13         RENAN_BARRERA_CONCHA                  0.890
# 14            JOAQUIN_DIAZ_MENA                  0.848
# 15         RENAN_BARRERA_CONCHA                  0.748
# 16         RENAN_BARRERA_CONCHA                  0.639
# 17         RENAN_BARRERA_CONCHA                  0.478
# 18  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.881
# 19         RENAN_BARRERA_CONCHA                  0.926
# 20         RENAN_BARRERA_CONCHA                  0.880
# 21         RENAN_BARRERA_CONCHA                  0.778
# 22         RENAN_BARRERA_CONCHA                  0.676
# 23         RENAN_BARRERA_CONCHA                  0.524
# 24  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.900
# 25         RENAN_BARRERA_CONCHA                  0.907
# 26         RENAN_BARRERA_CONCHA                  0.885
# 27         RENAN_BARRERA_CONCHA                  0.811
# 28         RENAN_BARRERA_CONCHA                  0.693
# 29         RENAN_BARRERA_CONCHA                  0.572
# 30  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.902
# 31         RENAN_BARRERA_CONCHA                  0.921
# 32         RENAN_BARRERA_CONCHA                  0.883
# 33         RENAN_BARRERA_CONCHA                  0.826
# 34         RENAN_BARRERA_CONCHA                  0.729
# 35         RENAN_BARRERA_CONCHA                  0.618
# 36  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.909
# 37         RENAN_BARRERA_CONCHA                  0.917
# 38   VIDA_ARAVARI_GOMEZ_HERRERA                  0.921
# 39         RENAN_BARRERA_CONCHA                  0.834
# 40         RENAN_BARRERA_CONCHA                  0.740
# 41         RENAN_BARRERA_CONCHA                  0.634
#
#     Cobertura_m_inter_q_025  Cobertura_m_inter_mediana  \
# 0                  0.082385                   0.087068
# 1                  0.057203                   0.060818
# 2                  0.040577                   0.042995
# 3                  0.025798                   0.027270
# 4                  0.018165                   0.019331
# 5                  0.012899                   0.013730
# 6                  0.000000                   0.011069
# 7                  0.058142                   0.061502
# 8                  0.040513                   0.043136
# 9                  0.025639                   0.027262
# 10                 0.018239                   0.019311
# 11                 0.012942                   0.013715
# 12                 0.000000                   0.011054
# 13                 0.057438                   0.060847
# 14                 0.040923                   0.043436
# 15                 0.025658                   0.027278
# 16                 0.018191                   0.019343
# 17                 0.012920                   0.013751
# 18                 0.000000                   0.010986
# 19                 0.057440                   0.060788
# 20                 0.040722                   0.043096
# 21                 0.025697                   0.027259
# 22                 0.018238                   0.019273
# 23                 0.012908                   0.013697
# 24                 0.000000                   0.011217
# 25                 0.057307                   0.060858
# 26                 0.040480                   0.043006
# 27                 0.025718                   0.027273
# 28                 0.018259                   0.019317
# 29                 0.012965                   0.013700
# 30                 0.000000                   0.012046
# 31                 0.057455                   0.060812
# 32                 0.040720                   0.042952
# 33                 0.025697                   0.027258
# 34                 0.018210                   0.019327
# 35                 0.012983                   0.013727
# 36                 0.000000                   0.012106
# 37                 0.057276                   0.060815
# 38                 0.014287                   0.016396
# 39                 0.025691                   0.027294
# 40                 0.018287                   0.019322
# 41                 0.012986                   0.013733
#
#     Cobertura_m_inter_q_975  Cob_JOAQUIN_DIAZ_MENA  Cob_RENAN_BARRERA_CONCHA  \
# 0                  0.092355                  0.904                     0.914
# 1                  0.064492                  0.864                     0.854
# 2                  0.045621                  0.795                     0.766
# 3                  0.029011                  0.638                     0.626
# 4                  0.020497                  0.521                     0.505
# 5                  0.014584                  0.383                     0.373
# 6                  0.019097                  0.939                     0.915
# 7                  0.065376                  0.890                     0.894
# 8                  0.045688                  0.844                     0.842
# 9                  0.028936                  0.694                     0.689
# 10                 0.020629                  0.598                     0.590
# 11                 0.014549                  0.459                     0.447
# 12                 0.018948                  0.925                     0.930
# 13                 0.064860                  0.899                     0.890
# 14                 0.046147                  0.848                     0.853
# 15                 0.028920                  0.752                     0.748
# 16                 0.020566                  0.655                     0.639
# 17                 0.014551                  0.495                     0.478
# 18                 0.019717                  0.933                     0.933
# 19                 0.064525                  0.937                     0.926
# 20                 0.045748                  0.888                     0.880
# 21                 0.028972                  0.784                     0.778
# 22                 0.020526                  0.688                     0.676
# 23                 0.014545                  0.548                     0.524
# 24                 0.019624                  0.936                     0.927
# 25                 0.064548                  0.923                     0.907
# 26                 0.045557                  0.898                     0.885
# 27                 0.028885                  0.824                     0.811
# 28                 0.020465                  0.709                     0.693
# 29                 0.014538                  0.598                     0.572
# 30                 0.018717                  0.937                     0.941
# 31                 0.064506                  0.927                     0.921
# 32                 0.045667                  0.890                     0.883
# 33                 0.028915                  0.840                     0.826
# 34                 0.020495                  0.751                     0.729
# 35                 0.014540                  0.638                     0.618
# 36                 0.019344                  0.941                     0.946
# 37                 0.064416                  0.923                     0.917
# 38                 0.018500                  0.925                     0.927
# 39                 0.028986                  0.856                     0.834
# 40                 0.020559                  0.778                     0.740
# 41                 0.014592                  0.672                     0.634
#
#     Cob_VIDA_ARAVARI_GOMEZ_HERRERA  Cob_VOTOS_NULOS_CAND_NO_REGIS  \
# 0                            0.916                          0.938
# 1                            0.894                          0.937
# 2                            0.832                          0.915
# 3                            0.739                          0.892
# 4                            0.619                          0.841
# 5                            0.461                          0.800
# 6                            0.919                          0.932
# 7                            0.907                          0.943
# 8                            0.874                          0.935
# 9                            0.823                          0.908
# 10                           0.706                          0.879
# 11                           0.584                          0.823
# 12                           0.933                          0.916
# 13                           0.924                          0.938
# 14                           0.886                          0.950
# 15                           0.852                          0.932
# 16                           0.734                          0.890
# 17                           0.619                          0.839
# 18                           0.935                          0.942
# 19                           0.936                          0.959
# 20                           0.918                          0.950
# 21                           0.862                          0.914
# 22                           0.761                          0.904
# 23                           0.672                          0.871
# 24                           0.934                          0.940
# 25                           0.931                          0.948
# 26                           0.927                          0.944
# 27                           0.870                          0.922
# 28                           0.808                          0.912
# 29                           0.688                          0.869
# 30                           0.947                          0.940
# 31                           0.944                          0.957
# 32                           0.942                          0.931
# 33                           0.873                          0.940
# 34                           0.799                          0.903
# 35                           0.752                          0.876
# 36                           0.922                          0.930
# 37                           0.924                          0.945
# 38                           0.921                          0.942
# 39                           0.902                          0.931
# 40                           0.861                          0.927
# 41                           0.745                          0.892
#
#     Cob_YAMIL_JASMIN_LOPEZ_MANRIQUE
# 0                             0.908
# 1                             0.903
# 2                             0.871
# 3                             0.795
# 4                             0.686
# 5                             0.544
# 6                             0.894
# 7                             0.925
# 8                             0.871
# 9                             0.822
# 10                            0.768
# 11                            0.641
# 12                            0.888
# 13                            0.928
# 14                            0.908
# 15                            0.833
# 16                            0.786
# 17                            0.673
# 18                            0.881
# 19                            0.941
# 20                            0.910
# 21                            0.874
# 22                            0.838
# 23                            0.712
# 24                            0.900
# 25                            0.935
# 26                            0.919
# 27                            0.898
# 28                            0.868
# 29                            0.773
# 30                            0.902
# 31                            0.938
# 32                            0.895
# 33                            0.907
# 34                            0.864
# 35                            0.782
# 36                            0.909
# 37                            0.938
# 38                            0.928
# 39                            0.899
# 40                            0.862
# 41                            0.811

# %%
# Guardamos en un csv
df_boostraps_votos_se.to_csv(r"/Users/damian/Documents/Tesis maestria/Bootstraps_codigos_bases/Bases finales rep/Bootstrap votos/Metodo 1/Distintas_muestras_submuestras_bootstrap_votos_met_1_sin_est_f_1.csv")

# %% [markdown]
# ## Estratificado (por distrito)

# %%
# Versión función
def boot_votos_estratificado(df_act_yuc_i, num_boot: int=1000, n_sample=None, n_vot_sub=2000, semilla = 1):

    # Listas auxiliares para guardar los datos
    est_punt_list=[]

    inter_list=[]

    # Cuantas votos hay por distrito
    array_frec_est=np.array(df_act_yuc_i.groupby('DISTRITO').agg({'TOTAL':'sum'}).reset_index(drop=True).astype(int)["TOTAL"])

    # Número de poblaciones
    n_boot=1000

    # Los valores distintos de los distritos
    val_dist=df_act_yuc_i["DISTRITO"].sort_values().unique()

    for i in range(num_boot):


        # Hacemos el muestreo de tamaño n_sample de las casilas estratificado por distrito
        df_stra_sam=fab.muestreo_estratificado_mej(df_act_yuc_i, ["DISTRITO"], sample_size=n_sample, semilla=i+1+(num_boot*semilla))

        # Guardamos en un numpy array el dataframe de la muestra
        array_muest=np.array(df_stra_sam[["DISTRITO","JOAQUIN_DIAZ_MENA","RENAN_BARRERA_CONCHA","VIDA_ARAVARI_GOMEZ_HERRERA","YAMIL_JASMIN_LOPEZ_MANRIQUE","VOTOS_NULOS_CAND_NO_REGIS"]])

        # Corrección porque el muestreo estratificado es de votos
        # Porcentaje del total de votos por estrato (distrito)
        array_pesos_normalizados_dist=np.array(df_stra_sam.groupby('DISTRITO').agg({'TOTAL':'sum'}).div(df_stra_sam["TOTAL"].sum()).sort_index()["TOTAL"])

        # Obtenemos los totales de las proporciones para cada estrato (distrito)
        totales_prop_est=fab.obtener_totales(array_pesos_normalizados_dist, n_vot_sub).astype(int)

        # Los porcentajes de cada distrito en la submuestra de votos
        array_pesos_normalizados_sub=totales_prop_est/totales_prop_est.sum()

        # Submuestra de votos por distrito (estrato)
        # Corrección del código inicial lo correcto es utilizar la distribución hipergeométrica multivariada.
        # Puesto que, se esta haciendo muestreo sin reemplazo y si utilizas la multinomial es muestreo con reemplazo.
        # La diferencia es mínima pero la hipergeométrica multivariada es la correcta.
        votos_subm_d=[np.random.default_rng(index+((i+1)+(num_boot*(semilla+1)))).multivariate_hypergeometric(colors=array_muest[array_muest[:,0]==val][:,1:].sum(0).astype(int), nsample=totales_prop_est[val-1]) for index, val in enumerate(val_dist)]

        # Vector de pesos de la distribución Dirichlet

        # Hay que arreglar la función para que pueda aceptar valores con alfa igual a cero (que tengan probabilidad 0)
        vectores_dir=[fab.f_a(xi,n_boot, semilla=index+((i+1)+(num_boot*(semilla+2)))) for index, xi in enumerate(votos_subm_d)]

        # Donde se van a guardar los resultados
        array_res=np.zeros((n_boot,5))

        # Completamos la muestra mediante el bootstrap bayesiano en cada estrato
        for k in val_dist:

            # Semilla para las muestras de la Multinomial
            rng_2 = np.random.default_rng((num_boot*(semilla+3))+(i+1+k))
            
            # Total de votos de la muestra simulada (utilizando una multinomial)
            votos_sim=rng_2.multinomial(n=array_frec_est[k-1],  pvals=vectores_dir[k-1])

            # Guardamos todo en un array con las estimaciones (se van sumando las iteraciones para alcnazar el 100%)
            array_res=array_res+(votos_sim/votos_sim.sum(1)[0]*array_pesos_normalizados_sub[k-1])

        # Los valores de los intervalos de probabilidad lower y upper
        inter_prob=np.concatenate((np.apply_along_axis(fab.inter_prob_l, axis=0, arr=array_res),np.apply_along_axis(fab.inter_prob_u, axis=0, arr=array_res)))

        # Estimaciones puntuales (del bootstrap)
        est_puntual=array_res.mean(0)

        # Guardamos las estimaciones puntuales
        est_punt_list.append(est_puntual)

        # Guardamos los intervalos
        inter_list.append(inter_prob)

    #print(df_stra_sam.shape[0])
    
    # Todas las estimaciones puntuales
    array_est_punt=np.array(est_punt_list)

    array_inter_prob=np.array(inter_list)
    
    return array_inter_prob,array_est_punt

# %%
inter_prob_v_est, est_punt_v_est=boot_votos_estratificado(df_act_yuc_i, num_boot=1000, n_sample=250, n_vot_sub=1000, semilla=1)

# %%
# Para medir cuanto tiempo se tarda en correr en promedio
# %timeit boot_votos_estratificado(df_act_yuc_i, num_boot=1000, n_sample=250, n_vot_sub=5000)
# Out:
# 11.4 s ± 286 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Cálculamos las métricas
df_metr_boot_v_est, df_error_max_v_est, df_can_cob_v_est = fab.metricas_bootstrap(prop_reales, inter_prob_v_est, est_punt_v_est, porcenta_tama=2000)

# %%
df_can_cob_v_est
# Out:
#                      Candidato  Numero_total_cob  Cobertura  Porcenta_tama
# 0            JOAQUIN_DIAZ_MENA               927      0.927           2000
# 1         RENAN_BARRERA_CONCHA               932      0.932           2000
# 2   VIDA_ARAVARI_GOMEZ_HERRERA               926      0.926           2000
# 3    VOTOS_NULOS_CAND_NO_REGIS               930      0.930           2000
# 4  YAMIL_JASMIN_LOPEZ_MANRIQUE               918      0.918           2000

# %%
# Candidato con intervalo más largo
df_inter_lar_v_est=df_metr_boot_v_est.groupby(["Candidato"]).agg({'Longitud_intervalo':'mean'}).reset_index()
df_inter_lar_v_est["Porcenta_tama"]=250
candidato_mas_largo_v_est=df_inter_lar_v_est[df_inter_lar_v_est["Longitud_intervalo"]==df_inter_lar_v_est["Longitud_intervalo"].max()]["Candidato"].values[0]

# %%
# Candidato con menor cobertura
candidato_cober_men_v_est=df_can_cob_v_est[df_can_cob_v_est["Cobertura"]==df_can_cob_v_est["Cobertura"].min()]["Candidato"].values[0]

# %%
df_error_max_v_est.describe(percentiles=[0.025,0.975])
# Out:
#        Num_bootstrap    Error_max  Porcenta_tama
# count    1000.000000  1000.000000         1000.0
# mean      500.500000     0.016654         2000.0
# std       288.819436     0.009386            0.0
# min         1.000000     0.000723         2000.0
# 2.5%       25.975000     0.004282         2000.0
# 50%       500.500000     0.014764         2000.0
# 97.5%     975.025000     0.039014         2000.0
# max      1000.000000     0.056791         2000.0

# %%
sns.set_theme();
ax = sns.catplot(
    data=df_error_max_v_est, x="Porcenta_tama", y="Error_max",
    kind="point", height=4, aspect=.7, errorbar='pi'
);
ax.set(xlabel='Porcentaje casillas', ylabel='Error');

# %%
# Base para poder hacer las gráficas de mínima cobertura e intervalos más largos
df_metr_boot_c_v_est=df_metr_boot_v_est.drop(columns="Cobertura").merge(df_can_cob_v_est[["Candidato","Cobertura"]], on=["Candidato"], how='left')
df_metr_boot_c_v_est
# Out:
#       Num_bootstrap  cuantil_025  cuantil_975  Longitud_intervalo  \
# 0                 1     0.477064     0.535293            0.058229
# 1                 2     0.467302     0.525819            0.058517
# 2                 3     0.513954     0.572825            0.058870
# 3                 4     0.482323     0.542296            0.059973
# 4                 5     0.498739     0.558585            0.059847
# ...             ...          ...          ...                 ...
# 4995            996     0.016958     0.036276            0.019317
# 4996            997     0.011617     0.028651            0.017034
# 4997            998     0.011493     0.026944            0.015451
# 4998            999     0.016114     0.035274            0.019160
# 4999           1000     0.009145     0.025025            0.015879
#
#       Estamacion_puntual  Porcentaje_real                  Candidato  \
# 0               0.506471         0.515125          JOAQUIN_DIAZ_MENA
# 1               0.496292         0.515125          JOAQUIN_DIAZ_MENA
# 2               0.543139         0.515125          JOAQUIN_DIAZ_MENA
# 3               0.512608         0.515125          JOAQUIN_DIAZ_MENA
# 4               0.528584         0.515125          JOAQUIN_DIAZ_MENA
# ...                  ...              ...                        ...
# 4995            0.025826         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4996            0.019112         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4997            0.018025         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4998            0.025599         0.021467  VOTOS_NULOS_CAND_NO_REGIS
# 4999            0.016050         0.021467  VOTOS_NULOS_CAND_NO_REGIS
#
#          Error  Porcenta_tama  Cobertura
# 0     0.008654           2000      0.887
# 1     0.018833           2000      0.887
# 2     0.028014           2000      0.887
# 3     0.002517           2000      0.887
# 4     0.013458           2000      0.887
# ...        ...            ...        ...
# 4995  0.004359           2000      0.942
# 4996  0.002355           2000      0.942
# 4997  0.003442           2000      0.942
# 4998  0.004132           2000      0.942
# 4999  0.005417           2000      0.942
#
# [5000 rows x 10 columns]

# %%
facet_kws={'sharey': False, 'sharex': True}
fig, axx =plt.subplots(2,1)
ax_1=sns.pointplot(
    data=df_metr_boot_c_v_est[df_metr_boot_c_v_est["Candidato"]==candidato_mas_largo_v_est], x="Porcenta_tama", y="Longitud_intervalo", errorbar='pi',ax=axx[0]
);
ax_2=sns.pointplot(
    data=df_metr_boot_c_v_est[df_metr_boot_c_v_est["Candidato"]==candidato_mas_largo_v_est].head(1), x="Porcenta_tama", y="Cobertura", ax=axx[1]
)
ax_1.set(xlabel='Porcentaje casillas', ylabel='Longitud intervalo');
ax_2.set(xlabel='Porcentaje casillas', ylabel='Cobertura');

# %%
facet_kws={'sharey': False, 'sharex': True}
fig, axx =plt.subplots(2,1)
ax_1=sns.pointplot(
    data=df_metr_boot_c_v_est[df_metr_boot_c_v_est["Candidato"]==candidato_cober_men_v_est], x="Porcenta_tama", y="Longitud_intervalo", errorbar='pi', ax=axx[0]
);
ax_2=sns.pointplot(
    data=df_metr_boot_c_v_est[df_metr_boot_c_v_est["Candidato"]==candidato_cober_men_v_est].head(1), x="Porcenta_tama", y="Cobertura", ax=axx[1]
)
ax_1.set(xlabel='Porcentaje casillas', ylabel='Longitud intervalo');
ax_2.set(xlabel='Porcentaje casillas', ylabel='Cobertura');

# %% [markdown]
# ### Bootstraps con distintas muestras de casillas y submuestras de votos

# %%
# Probamos distintos valores de tamaño de la muestra de las casillas y la submuestra de votos
muestra_casillas = [100, 150, 200, 250, 300, 350, 400]
submuestra_votos = [500, 1000, 2000, 5000, 10000, 20000]

# Dataframe donde se guardará todo
df_boostraps_votos_ec=pd.DataFrame()

# Contador para el for
k=0

# Hacemos los for sobre el tamaño de las muestras y submuestras
for mc in muestra_casillas:
    for smv in submuestra_votos:
        # Para medir cuanto tiempo se tarda en correr
        loop_time = time.time()
        # Boostrap por votos (estratificado)
        inter_prob_v_est, est_punt_v_est=boot_votos_estratificado(df_act_yuc_i, num_boot=1000, n_sample=mc, n_vot_sub=smv)

        # Calculamos las métricas
        df_metr_boot_v_est, df_error_max_v_est, df_can_cob_v_est = fab.metricas_bootstrap(prop_reales, inter_prob_v_est, est_punt_v_est, porcenta_tama=mc)

        # Los valores de las muestra y submuestras
        df_boostraps_votos_ec.loc[k,["Tamaño_muestra_casillas","Tamaño_submuestra_votos"]]=[mc,smv]

        # Las métricas para el error máximo
        df_boostraps_votos_ec.loc[k,["Error_maximo_q_025","Error_maximo_mediana","Error_maximo_q_975"]]=df_error_max_v_est["Error_max"].quantile([0.025,0.5,0.975]).to_list()

        # Calculamos el candidato que tenga intervalos más largos (en promedio)
        candidato_int_est_m_l=df_metr_boot_v_est.groupby(["Candidato"]).agg({'Longitud_intervalo':'mean'}).reset_index()["Candidato"].values[0]
        # Candidato con el intervalos más grandes
        df_boostraps_votos_ec.loc[k, "Intervalo_M_grande_candidato_nom"]=candidato_int_est_m_l
        # Cobertura del candidato con el intervalos más grandes
        df_boostraps_votos_ec.loc[k, ["Intervalo_M_grande_candidato_cob"]]=df_can_cob_v_est[df_can_cob_v_est["Candidato"]==candidato_int_est_m_l]["Cobertura"].values[0]
        # Las métricas del candidato con los intervalos más grandes
        df_boostraps_votos_ec.loc[k,["Intervalo_M_grande_inter_q_025","Intervalo_M_grande_inter_mediana","Intervalo_M_grande_inter_q_975"]]=df_metr_boot_v_est[df_metr_boot_v_est["Candidato"]==candidato_int_est_m_l]["Longitud_intervalo"].quantile([0.025,0.5,0.975]).to_list()

        # Calculamos el candidato con la menor cobertura
        # Candidato con menor cobertura
        candidato_cober_est_men_v=df_can_cob_v_est[df_can_cob_v_est["Cobertura"]==df_can_cob_v_est["Cobertura"].min()]["Candidato"].values[0]

        # Candidato con el intervalos más grandes
        df_boostraps_votos_ec.loc[k, "Cobertura_m_candidato_nom"]=candidato_cober_est_men_v
        # Cobertura del candidato con menor cobertura
        df_boostraps_votos_ec.loc[k, ["Cobertura_m_candidato"]]=df_can_cob_v_est[df_can_cob_v_est["Candidato"]==candidato_cober_est_men_v]["Cobertura"].values[0]
        # Las métricas del candidato con la menor cobertura
        df_boostraps_votos_ec.loc[k,["Cobertura_m_inter_q_025","Cobertura_m_inter_mediana","Cobertura_m_inter_q_975"]]=df_metr_boot_v_est[df_metr_boot_v_est["Candidato"]==candidato_cober_est_men_v]["Longitud_intervalo"].quantile([0.025,0.5,0.975]).to_list()

        # Coberturas de los candidatos en el bootstrap 
        df_boostraps_votos_ec.loc[k, ["Cob_JOAQUIN_DIAZ_MENA","Cob_RENAN_BARRERA_CONCHA","Cob_VIDA_ARAVARI_GOMEZ_HERRERA","Cob_VOTOS_NULOS_CAND_NO_REGIS","Cob_YAMIL_JASMIN_LOPEZ_MANRIQUE"]]=df_can_cob_v_est.sort_values(by="Candidato")["Cobertura"].to_list()

        k=k+1
        
        print("Muestra casillas:", mc, "Submuestra votos:", smv)
        print('Tiempo que tarda correr una iteración del for {}'.format((time.time() - loop_time)))  

# Lo guardamos en otra base copia por si sin querer pongo a correr el código
df_boostraps_votos_ec_f=df_boostraps_votos_ec.copy()
# Out:
# Muestra casillas: 100 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.461609840393066
# Muestra casillas: 100 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.232874870300293
# Muestra casillas: 100 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.497835874557495
# Muestra casillas: 100 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.555238246917725
# Muestra casillas: 100 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 11.153828859329224
# Muestra casillas: 100 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 11.54113483428955
# Muestra casillas: 150 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.26150107383728
# Muestra casillas: 150 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 8.884875059127808
# Muestra casillas: 150 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 9.893789768218994
# Muestra casillas: 150 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.788178205490112
# Muestra casillas: 150 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 11.327504873275757
# Muestra casillas: 150 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 10.98691201210022
# Muestra casillas: 200 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.48807406425476
# Muestra casillas: 200 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.211225986480713
# Muestra casillas: 200 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.133800029754639
# Muestra casillas: 200 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.78430986404419
# Muestra casillas: 200 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 11.032737016677856
# Muestra casillas: 200 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 10.909538984298706
# Muestra casillas: 250 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.319208860397339
# Muestra casillas: 250 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.293752908706665
# Muestra casillas: 250 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.194145202636719
# Muestra casillas: 250 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.670907258987427
# Muestra casillas: 250 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 10.735555171966553
# Muestra casillas: 250 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 11.086400032043457
# Muestra casillas: 300 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.91094183921814
# Muestra casillas: 300 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.295200109481812
# Muestra casillas: 300 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.381480932235718
# Muestra casillas: 300 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.658748149871826
# Muestra casillas: 300 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 10.738103866577148
# Muestra casillas: 300 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 10.860400199890137
# Muestra casillas: 350 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.247424840927124
# Muestra casillas: 350 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.256296873092651
# Muestra casillas: 350 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.261101007461548
# Muestra casillas: 350 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.836709022521973
# Muestra casillas: 350 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 11.12224793434143
# Muestra casillas: 350 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 11.262298107147217
# Muestra casillas: 400 Submuestra votos: 500
# Tiempo que tarda correr una iteración del for 8.613460063934326
# Muestra casillas: 400 Submuestra votos: 1000
# Tiempo que tarda correr una iteración del for 9.318068981170654
# Muestra casillas: 400 Submuestra votos: 2000
# Tiempo que tarda correr una iteración del for 10.215383052825928
# Muestra casillas: 400 Submuestra votos: 5000
# Tiempo que tarda correr una iteración del for 10.772000074386597
# Muestra casillas: 400 Submuestra votos: 10000
# Tiempo que tarda correr una iteración del for 10.762120008468628
# Muestra casillas: 400 Submuestra votos: 20000
# Tiempo que tarda correr una iteración del for 11.237138748168945

# %%
df_boostraps_votos_ec_f
# Out:
#    Tamaño_muestra_casillas Tamaño_submuestra_votos  Error_maximo_q_025  \
# 0                      100                     500            0.005423
# 1                      100                    1000            0.003838
# 2                      100                    2000            0.003044
# 3                      100                    5000            0.002506
# 4                      100                   10000            0.002228
# 5                      100                   20000            0.002017
# 6                      150                     500            0.005354
# 7                      150                    1000            0.003646
# 8                      150                    2000            0.002947
# 9                      150                    5000            0.002361
# 10                     150                   10000            0.001872
# 11                     150                   20000            0.001729
# 12                     200                     500            0.004996
# 13                     200                    1000            0.004014
# 14                     200                    2000            0.002667
# 15                     200                    5000            0.001984
# 16                     200                   10000            0.001702
# 17                     200                   20000            0.001519
# 18                     250                     500            0.005118
# 19                     250                    1000            0.004282
# 20                     250                    2000            0.003060
# 21                     250                    5000            0.002097
# 22                     250                   10000            0.001370
# 23                     250                   20000            0.001413
# 24                     300                     500            0.005012
# 25                     300                    1000            0.003501
# 26                     300                    2000            0.002760
# 27                     300                    5000            0.001699
# 28                     300                   10000            0.001490
# 29                     300                   20000            0.001323
# 30                     350                     500            0.005030
# 31                     350                    1000            0.003921
# 32                     350                    2000            0.002848
# 33                     350                    5000            0.001780
# 34                     350                   10000            0.001449
# 35                     350                   20000            0.001298
# 36                     400                     500            0.004735
# 37                     400                    1000            0.003602
# 38                     400                    2000            0.002621
# 39                     400                    5000            0.001810
# 40                     400                   10000            0.001418
# 41                     400                   20000            0.001152
#
#     Error_maximo_mediana  Error_maximo_q_975 Intervalo_M_grande_candidato_nom  \
# 0               0.019495            0.055754                JOAQUIN_DIAZ_MENA
# 1               0.015259            0.042669                JOAQUIN_DIAZ_MENA
# 2               0.012976            0.035223                JOAQUIN_DIAZ_MENA
# 3               0.010168            0.028879                JOAQUIN_DIAZ_MENA
# 4               0.009189            0.027675                JOAQUIN_DIAZ_MENA
# 5               0.008716            0.026219                JOAQUIN_DIAZ_MENA
# 6               0.020439            0.056494                JOAQUIN_DIAZ_MENA
# 7               0.014869            0.041717                JOAQUIN_DIAZ_MENA
# 8               0.011686            0.032177                JOAQUIN_DIAZ_MENA
# 9               0.009630            0.025810                JOAQUIN_DIAZ_MENA
# 10              0.008713            0.023041                JOAQUIN_DIAZ_MENA
# 11              0.008255            0.021205                JOAQUIN_DIAZ_MENA
# 12              0.020403            0.052947                JOAQUIN_DIAZ_MENA
# 13              0.014658            0.038862                JOAQUIN_DIAZ_MENA
# 14              0.011433            0.029926                JOAQUIN_DIAZ_MENA
# 15              0.008517            0.022660                JOAQUIN_DIAZ_MENA
# 16              0.007160            0.019279                JOAQUIN_DIAZ_MENA
# 17              0.006371            0.017964                JOAQUIN_DIAZ_MENA
# 18              0.020261            0.052619                JOAQUIN_DIAZ_MENA
# 19              0.014764            0.039014                JOAQUIN_DIAZ_MENA
# 20              0.011105            0.029661                JOAQUIN_DIAZ_MENA
# 21              0.008240            0.021997                JOAQUIN_DIAZ_MENA
# 22              0.007054            0.018698                JOAQUIN_DIAZ_MENA
# 23              0.006326            0.016954                JOAQUIN_DIAZ_MENA
# 24              0.019015            0.051481                JOAQUIN_DIAZ_MENA
# 25              0.013814            0.038531                JOAQUIN_DIAZ_MENA
# 26              0.010641            0.028276                JOAQUIN_DIAZ_MENA
# 27              0.007484            0.021284                JOAQUIN_DIAZ_MENA
# 28              0.006333            0.017740                JOAQUIN_DIAZ_MENA
# 29              0.005528            0.015784                JOAQUIN_DIAZ_MENA
# 30              0.018473            0.055077                JOAQUIN_DIAZ_MENA
# 31              0.013638            0.038210                JOAQUIN_DIAZ_MENA
# 32              0.010180            0.027136                JOAQUIN_DIAZ_MENA
# 33              0.007174            0.019987                JOAQUIN_DIAZ_MENA
# 34              0.005876            0.017008                JOAQUIN_DIAZ_MENA
# 35              0.005191            0.015387                JOAQUIN_DIAZ_MENA
# 36              0.018944            0.051783                JOAQUIN_DIAZ_MENA
# 37              0.013785            0.039001                JOAQUIN_DIAZ_MENA
# 38              0.010313            0.027953                JOAQUIN_DIAZ_MENA
# 39              0.007391            0.021077                JOAQUIN_DIAZ_MENA
# 40              0.006072            0.017648                JOAQUIN_DIAZ_MENA
# 41              0.005400            0.015187                JOAQUIN_DIAZ_MENA
#
#     Intervalo_M_grande_candidato_cob  Intervalo_M_grande_inter_q_025  \
# 0                              0.911                        0.076984
# 1                              0.896                        0.055796
# 2                              0.856                        0.039905
# 3                              0.742                        0.025316
# 4                              0.620                        0.018042
# 5                              0.485                        0.012733
# 6                              0.919                        0.077092
# 7                              0.906                        0.055520
# 8                              0.865                        0.039853
# 9                              0.783                        0.025413
# 10                             0.650                        0.018121
# 11                             0.517                        0.012872
# 12                             0.927                        0.077288
# 13                             0.919                        0.055686
# 14                             0.900                        0.039634
# 15                             0.828                        0.025399
# 16                             0.744                        0.017999
# 17                             0.629                        0.012904
# 18                             0.918                        0.076969
# 19                             0.927                        0.055741
# 20                             0.904                        0.039980
# 21                             0.846                        0.025572
# 22                             0.762                        0.018112
# 23                             0.644                        0.012851
# 24                             0.928                        0.076894
# 25                             0.933                        0.056328
# 26                             0.923                        0.039856
# 27                             0.874                        0.025528
# 28                             0.798                        0.018043
# 29                             0.688                        0.012806
# 30                             0.931                        0.076817
# 31                             0.933                        0.055807
# 32                             0.932                        0.039841
# 33                             0.899                        0.025286
# 34                             0.827                        0.018050
# 35                             0.744                        0.012780
# 36                             0.929                        0.077181
# 37                             0.923                        0.055822
# 38                             0.919                        0.040128
# 39                             0.879                        0.025486
# 40                             0.813                        0.018042
# 41                             0.731                        0.012834
#
#     Intervalo_M_grande_inter_mediana  Intervalo_M_grande_inter_q_975  \
# 0                           0.081911                        0.087329
# 1                           0.059271                        0.062766
# 2                           0.042275                        0.044956
# 3                           0.026910                        0.028611
# 4                           0.019127                        0.020266
# 5                           0.013592                        0.014452
# 6                           0.081947                        0.087324
# 7                           0.059313                        0.062602
# 8                           0.042186                        0.044977
# 9                           0.026967                        0.028759
# 10                          0.019143                        0.020246
# 11                          0.013594                        0.014434
# 12                          0.081996                        0.087401
# 13                          0.059217                        0.063078
# 14                          0.042343                        0.045018
# 15                          0.026935                        0.028575
# 16                          0.019133                        0.020278
# 17                          0.013614                        0.014410
# 18                          0.082087                        0.087374
# 19                          0.059292                        0.063038
# 20                          0.042407                        0.044913
# 21                          0.027065                        0.028674
# 22                          0.019164                        0.020258
# 23                          0.013628                        0.014450
# 24                          0.082100                        0.087493
# 25                          0.059288                        0.062940
# 26                          0.042410                        0.044897
# 27                          0.027038                        0.028785
# 28                          0.019150                        0.020315
# 29                          0.013622                        0.014404
# 30                          0.082169                        0.087591
# 31                          0.059236                        0.062808
# 32                          0.042329                        0.044979
# 33                          0.027083                        0.028601
# 34                          0.019197                        0.020327
# 35                          0.013619                        0.014454
# 36                          0.082370                        0.087642
# 37                          0.059280                        0.063066
# 38                          0.042486                        0.045222
# 39                          0.026991                        0.028713
# 40                          0.019206                        0.020349
# 41                          0.013643                        0.014518
#
#       Cobertura_m_candidato_nom  Cobertura_m_candidato  \
# 0   YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.886
# 1          RENAN_BARRERA_CONCHA                  0.888
# 2          RENAN_BARRERA_CONCHA                  0.836
# 3          RENAN_BARRERA_CONCHA                  0.713
# 4          RENAN_BARRERA_CONCHA                  0.603
# 5          RENAN_BARRERA_CONCHA                  0.460
# 6    VIDA_ARAVARI_GOMEZ_HERRERA                  0.898
# 7             JOAQUIN_DIAZ_MENA                  0.906
# 8             JOAQUIN_DIAZ_MENA                  0.865
# 9          RENAN_BARRERA_CONCHA                  0.764
# 10         RENAN_BARRERA_CONCHA                  0.639
# 11         RENAN_BARRERA_CONCHA                  0.502
# 12  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.894
# 13   VIDA_ARAVARI_GOMEZ_HERRERA                  0.918
# 14         RENAN_BARRERA_CONCHA                  0.895
# 15         RENAN_BARRERA_CONCHA                  0.825
# 16         RENAN_BARRERA_CONCHA                  0.721
# 17         RENAN_BARRERA_CONCHA                  0.601
# 18  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.907
# 19  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.918
# 20            JOAQUIN_DIAZ_MENA                  0.904
# 21         RENAN_BARRERA_CONCHA                  0.842
# 22         RENAN_BARRERA_CONCHA                  0.756
# 23         RENAN_BARRERA_CONCHA                  0.619
# 24  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.891
# 25   VIDA_ARAVARI_GOMEZ_HERRERA                  0.915
# 26  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.901
# 27         RENAN_BARRERA_CONCHA                  0.854
# 28         RENAN_BARRERA_CONCHA                  0.793
# 29         RENAN_BARRERA_CONCHA                  0.677
# 30  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.905
# 31    VOTOS_NULOS_CAND_NO_REGIS                  0.929
# 32   VIDA_ARAVARI_GOMEZ_HERRERA                  0.912
# 33         RENAN_BARRERA_CONCHA                  0.898
# 34         RENAN_BARRERA_CONCHA                  0.819
# 35         RENAN_BARRERA_CONCHA                  0.708
# 36  YAMIL_JASMIN_LOPEZ_MANRIQUE                  0.915
# 37    VOTOS_NULOS_CAND_NO_REGIS                  0.920
# 38         RENAN_BARRERA_CONCHA                  0.918
# 39         RENAN_BARRERA_CONCHA                  0.873
# 40         RENAN_BARRERA_CONCHA                  0.805
# 41         RENAN_BARRERA_CONCHA                  0.716
#
#     Cobertura_m_inter_q_025  Cobertura_m_inter_mediana  \
# 0                  0.000000                   0.011678
# 1                  0.054967                   0.058385
# 2                  0.039171                   0.041674
# 3                  0.025089                   0.026544
# 4                  0.017782                   0.018832
# 5                  0.012650                   0.013401
# 6                  0.022483                   0.030682
# 7                  0.055520                   0.059313
# 8                  0.039853                   0.042186
# 9                  0.025065                   0.026555
# 10                 0.017842                   0.018867
# 11                 0.012677                   0.013418
# 12                 0.000000                   0.010718
# 13                 0.018299                   0.022441
# 14                 0.039269                   0.041664
# 15                 0.025062                   0.026587
# 16                 0.017832                   0.018886
# 17                 0.012693                   0.013449
# 18                 0.000000                   0.010675
# 19                 0.003535                   0.008509
# 20                 0.039980                   0.042407
# 21                 0.025188                   0.026622
# 22                 0.017808                   0.018914
# 23                 0.012718                   0.013444
# 24                 0.000000                   0.011006
# 25                 0.018425                   0.022395
# 26                 0.003777                   0.006107
# 27                 0.025099                   0.026667
# 28                 0.017768                   0.018895
# 29                 0.012692                   0.013443
# 30                 0.000000                   0.011497
# 31                 0.013476                   0.017242
# 32                 0.014018                   0.016102
# 33                 0.025074                   0.026674
# 34                 0.017756                   0.018886
# 35                 0.012685                   0.013432
# 36                 0.000000                   0.010581
# 37                 0.013213                   0.017297
# 38                 0.039622                   0.041850
# 39                 0.025057                   0.026686
# 40                 0.017748                   0.018875
# 41                 0.012696                   0.013446
#
#     Cobertura_m_inter_q_975  Cob_JOAQUIN_DIAZ_MENA  Cob_RENAN_BARRERA_CONCHA  \
# 0                  0.018993                  0.911                     0.909
# 1                  0.062154                  0.896                     0.888
# 2                  0.044237                  0.856                     0.836
# 3                  0.028114                  0.742                     0.713
# 4                  0.020069                  0.620                     0.603
# 5                  0.014263                  0.485                     0.460
# 6                  0.037561                  0.919                     0.921
# 7                  0.062602                  0.906                     0.919
# 8                  0.044977                  0.865                     0.876
# 9                  0.028196                  0.783                     0.764
# 10                 0.019968                  0.650                     0.639
# 11                 0.014228                  0.517                     0.502
# 12                 0.018369                  0.927                     0.930
# 13                 0.026343                  0.919                     0.919
# 14                 0.044386                  0.900                     0.895
# 15                 0.028152                  0.828                     0.825
# 16                 0.020017                  0.744                     0.721
# 17                 0.014228                  0.629                     0.601
# 18                 0.018220                  0.918                     0.929
# 19                 0.012241                  0.927                     0.932
# 20                 0.044913                  0.904                     0.915
# 21                 0.028327                  0.846                     0.842
# 22                 0.020157                  0.762                     0.756
# 23                 0.014268                  0.644                     0.619
# 24                 0.018541                  0.928                     0.930
# 25                 0.026373                  0.933                     0.939
# 26                 0.008133                  0.923                     0.916
# 27                 0.028321                  0.874                     0.854
# 28                 0.020084                  0.798                     0.793
# 29                 0.014243                  0.688                     0.677
# 30                 0.017881                  0.931                     0.943
# 31                 0.021109                  0.933                     0.943
# 32                 0.018189                  0.932                     0.929
# 33                 0.028281                  0.899                     0.898
# 34                 0.019973                  0.827                     0.819
# 35                 0.014247                  0.744                     0.708
# 36                 0.017944                  0.929                     0.932
# 37                 0.021339                  0.923                     0.930
# 38                 0.044400                  0.919                     0.918
# 39                 0.028156                  0.879                     0.873
# 40                 0.020044                  0.813                     0.805
# 41                 0.014248                  0.731                     0.716
#
#     Cob_VIDA_ARAVARI_GOMEZ_HERRERA  Cob_VOTOS_NULOS_CAND_NO_REGIS  \
# 0                            0.915                          0.922
# 1                            0.905                          0.914
# 2                            0.867                          0.910
# 3                            0.773                          0.889
# 4                            0.640                          0.853
# 5                            0.490                          0.787
# 6                            0.898                          0.914
# 7                            0.928                          0.920
# 8                            0.882                          0.918
# 9                            0.810                          0.920
# 10                           0.714                          0.888
# 11                           0.602                          0.826
# 12                           0.919                          0.940
# 13                           0.918                          0.918
# 14                           0.902                          0.925
# 15                           0.841                          0.925
# 16                           0.780                          0.893
# 17                           0.653                          0.829
# 18                           0.943                          0.919
# 19                           0.926                          0.930
# 20                           0.906                          0.920
# 21                           0.862                          0.911
# 22                           0.802                          0.906
# 23                           0.708                          0.863
# 24                           0.930                          0.934
# 25                           0.915                          0.937
# 26                           0.911                          0.934
# 27                           0.898                          0.929
# 28                           0.859                          0.917
# 29                           0.752                          0.883
# 30                           0.924                          0.921
# 31                           0.930                          0.929
# 32                           0.912                          0.932
# 33                           0.906                          0.931
# 34                           0.854                          0.910
# 35                           0.789                          0.890
# 36                           0.925                          0.924
# 37                           0.925                          0.920
# 38                           0.921                          0.928
# 39                           0.875                          0.946
# 40                           0.850                          0.922
# 41                           0.773                          0.891
#
#     Cob_YAMIL_JASMIN_LOPEZ_MANRIQUE
# 0                             0.886
# 1                             0.907
# 2                             0.882
# 3                             0.784
# 4                             0.698
# 5                             0.559
# 6                             0.907
# 7                             0.914
# 8                             0.886
# 9                             0.834
# 10                            0.775
# 11                            0.666
# 12                            0.894
# 13                            0.920
# 14                            0.910
# 15                            0.868
# 16                            0.796
# 17                            0.706
# 18                            0.907
# 19                            0.918
# 20                            0.918
# 21                            0.889
# 22                            0.813
# 23                            0.738
# 24                            0.891
# 25                            0.939
# 26                            0.901
# 27                            0.899
# 28                            0.854
# 29                            0.751
# 30                            0.905
# 31                            0.940
# 32                            0.921
# 33                            0.905
# 34                            0.854
# 35                            0.801
# 36                            0.915
# 37                            0.926
# 38                            0.927
# 39                            0.908
# 40                            0.874
# 41                            0.807

# %%
# Guardamos la base en un csv
df_boostraps_votos_ec_f.to_csv("/Users/damian/Documents/Tesis maestria/Bootstraps_codigos_bases/Bases finales rep/Bootstrap votos/Metodo 1/Distintas_muestras_submuestras_bootstrap_votos_met_1_estratificado_f_1.csv")
